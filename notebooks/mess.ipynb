# %% [markdown]
# Mess is a layer between `nn.Module` and the compiler of `aioway`,
# it sits there providing information as to what flags to expect, and what signature to pass.

# %%
from aioway.mess import *

# %%
from torch import nn

# %%
find_mess(nn.Linear)

# %%
find_mess(nn.Bilinear)

# %%
find_mess(nn.Dropout)

# %%
find_mess(nn.Dropout1d)

# %%
find_mess(nn.Dropout2d)

# %%
find_mess(nn.Dropout3d)

# %%
find_mess(nn.Conv1d)

# %%
find_mess(nn.Conv2d)

# %%
find_mess(nn.Conv3d)

# %%
find_mess(nn.MaxPool1d)

# %%
find_mess(nn.MaxPool2d)

# %%
find_mess(nn.MaxPool3d)

# %%
find_mess(nn.AvgPool1d)

# %%
find_mess(nn.AvgPool2d)

# %%
find_mess(nn.AvgPool3d)

# %%
find_mess(nn.L1Loss)

# %%
find_mess(nn.MSELoss)

# %%
find_mess(nn.CTCLoss)

# %%
find_mess(nn.SmoothL1Loss)

# %%
find_mess(nn.KLDivLoss)

# %%
find_mess(nn.NLLLoss)

# %%
find_mess(nn.ReLU)

# %%
find_mess(nn.ReLU6)

# %%
find_mess(nn.Sigmoid)

# %%
find_mess(nn.Tanh)

# %%
find_mess(nn.Softmax)

# %%
find_mess(nn.LogSoftmax)
