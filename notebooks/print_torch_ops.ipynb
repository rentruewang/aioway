# %%
import torch

# %%
from aioway._torch import torch_fake_mode
from aioway.modes import PrintTorDis, PrintTorFunc

# %%
a = torch.randn(3, 4)
b = torch.randn(1, 1)

# %%
with PrintTorDis().enter(), PrintTorFunc().enter():
    c = a + b

# %%
c

# %%
with torch_fake_mode():
    a = torch.randn(3, 4)
    b = torch.randn(1, 1)

# %%
with PrintTorDis().enter(), PrintTorFunc().enter():
    c = a + b

# %%
c
